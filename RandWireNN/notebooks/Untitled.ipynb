# %%
from tensorboardX import SummaryWriter
writer = SummaryWriter('runs/exp-1')
writer2 = SummaryWriter()
writer3 = SummaryWriter(comment='3x learning rate')

# %%
from torchsummary import summary

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torch.autograd import Variable
from tensorboardX import SummaryWriter

dummy_input = (torch.zeros(1, 3),)


class LinearInLinear(nn.Module):
    def __init__(self):
        super(LinearInLinear, self).__init__()
        self.l = nn.Linear(3, 5)

    def forward(self, x):
        return self.l(x)

with SummaryWriter(comment='LinearInLinear') as w:
    w.add_graph(LinearInLinear(), dummy_input, True)
# Out:
# graph(%input : Float(1, 3),
#       %1 : Float(5, 3),
#       %2 : Float(5)):
#   %3 : Float(3!, 5!) = onnx::Transpose[perm=[1, 0]](%1), scope: LinearInLinear/Linear[l]
#   %4 : Float(1, 5) = onnx::Gemm[alpha=1, beta=1](%input, %3, %2), scope: LinearInLinear/Linear[l]
#   return (%4)

# %%
import os
import time
import torch
import logging
import argparse
import easydict

import sys
from model.model import RandWire
from utils.train import train
from utils.hparams import HParam
from utils.writer import MyWriter
from utils.graph_reader import read_graph
from dataset.dataloader import create_dataloader, MNIST_dataloader, CIFAR10_dataloader

import os
import math
import tqdm
import torch
import torch.nn as nn
import torch.nn.functional as F
import adabound
import itertools
import traceback
from torchsummary import summary

from utils.hparams import load_hparam_str
from utils.evaluation import validate
from model.model import RandWire



if __name__ == '__main__':
#     parser = argparse.ArgumentParser()
#     parser.add_argument('-c', '--config', type=str, required=True,
#                         help="yaml file for configuration")
#     parser.add_argument('-p', '--checkpoint_path', type=str, default=None, required=False,
#                         help="path of checkpoint pt file")
#     parser.add_argument('-m', '--model', type=str, required=True,
#                         help="name of the model. used for logging/saving checkpoints")
#     args = parser.parse_args()

    args = easydict.EasyDict({
 
        "config": './config/config.yaml',
 
        "checkpoint_path": None,
 
        "model": 'test'

 
})

    
    hp = HParam(args.config)
    with open(args.config, 'r') as f:
        hp_str = ''.join(f.readlines())

    pt_path = os.path.join('.', hp.log.chkpt_dir)
    out_dir = os.path.join(pt_path, args.model)
    os.makedirs(out_dir, exist_ok=True)

    log_dir = os.path.join('.', hp.log.log_dir)
    log_dir = os.path.join(log_dir, args.model)
    os.makedirs(log_dir, exist_ok=True)

    if args.checkpoint_path is not None:
        chkpt_path = args.checkpoint_path
    else:
        chkpt_path = None

    logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s',
        handlers=[
            logging.FileHandler(os.path.join(log_dir,
                '%s-%d.log' % (args.model, time.time()))),
            logging.StreamHandler()
        ]
    )
    logger = logging.getLogger()
    
    if hp.data.train == '' or hp.data.val == '':
        logger.error("hp.data.train, hp.data.val cannot be empty")
        raise Exception("Please specify directories of train data.")

    if hp.model.graph0 == '' or hp.model.graph1 == '' or hp.model.graph2 == '':
        logger.error("hp.model.graph0, graph1, graph2 cannot be empty")
        raise Exception("Please specify random DAG architecture.")

    graphs = [
        read_graph(hp.model.graph0),
        read_graph(hp.model.graph1),
        read_graph(hp.model.graph2),
    ]

    writer = MyWriter(log_dir)
    
    dataset = hp.data.type
    switcher = {
            'MNIST': MNIST_dataloader,
            'CIFAR10':CIFAR10_dataloader,
            'ImageNet':create_dataloader,
            }
    assert dataset in switcher.keys(), 'Dataset type currently not supported'
    dl_func = switcher[dataset]
    trainset = dl_func(hp, args, True)
    valset = dl_func(hp, args, False)

    #train(out_dir, chkpt_path, trainset, valset, writer, logger, hp, hp_str, graphs)
    
    
################# Train
    model = RandWire(hp, graphs).cuda()
    if hp.train.optimizer == 'adam':
        optimizer = torch.optim.Adam(model.parameters(),
                                     lr=hp.train.adam)
    elif hp.train.optimizer == 'adabound':
        optimizer = adabound.AdaBound(model.parameters(),
                             lr=hp.train.adabound.initial,
                             final_lr=hp.train.adabound.final)
    elif hp.train.optimizer == 'sgd':
        optimizer = torch.optim.SGD(model.parameters(),
                                    lr=hp.train.sgd.lr,
                                    momentum=hp.train.sgd.momentum,
                                    weight_decay=hp.train.sgd.weight_decay)
    else:
        raise Exception("Optimizer not supported: %s" % hp.train.optimizer)

    lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer, hp.train.epoch)

    init_epoch = -1
    step = 0

    if chkpt_path is not None:
        logger.info("Resuming from checkpoint: %s" % chkpt_path)
        checkpoint = torch.load(chkpt_path)
        model.load_state_dict(checkpoint['model'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        lr_scheduler.load_state_dict(checkpoint['lr_scheduler'])
        step = checkpoint['step']
        init_epoch = checkpoint['epoch']

        if hp_str != checkpoint['hp_str']:
            logger.warning("New hparams are different from checkpoint.")
            logger.warning("Will use new hparams.")
        # hp = load_hparam_str(hp_str)
    else:
        logger.info("Starting new training run")
        logger.info("Writing graph to tensorboardX...")
        #print(model)
        parameters = 0
        for p in list(model.parameters()):
            nn =1
            for s in list(p.size()):
                nn = nn * s
            parameters += nn
        #print("Parameters",parameters)
        writer.write_graph(model, torch.randn(7, hp.model.input_maps, 224, 224).cuda())
        logger.info("Finished.")

    try:
        model.train()
        for epoch in itertools.count(init_epoch+1):
            loader = tqdm.tqdm(trainset, desc='Train data loader')
            for data, target in loader:
                data, target = data.cuda(), target.cuda()
                optimizer.zero_grad()
                output = model(data)
                loss = F.nll_loss(output, target)
                loss.backward()
                optimizer.step()
                
                loss = loss.item()
                if loss > 1e8 or math.isnan(loss):
                    logger.error("Loss exploded to %.02f at step %d!" % (loss, step))
                    raise Exception("Loss exploded")

                writer.log_training(loss, step)
                loader.set_description('Loss %.02f at step %d' % (loss, step))
                step += 1                

            save_path = os.path.join(out_dir, 'chkpt_%03d.pt' % epoch)
            torch.save({
                'model': model.state_dict(),
                'optimizer': optimizer.state_dict(),
                'lr_scheduler': lr_scheduler.state_dict(),
                'step': step,
                'epoch': epoch,
                'hp_str': hp_str,
            }, save_path)
            logger.info("Saved checkpoint to: %s" % save_path)

            validate(model, valset, writer, epoch)
            lr_scheduler.step()

    except Exception as e:
        logger.info("Exiting due to exception: %s" % e)
        traceback.print_exc()
# Out:
# 2019-07-08 14:03:35,217 - INFO - Starting new training run
# 2019-07-08 14:03:35,218 - INFO - Writing graph to tensorboardX...
# 2019-07-08 14:03:37,362 - INFO - Finished.
#
# Train data loader:   0%|                                                                      | 0/8572 [00:00<?, ?it/s]
# Loss 2.22 at step 3:   0%|                                                            | 4/8572 [00:01<52:30,  2.72it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-2f552d031dea> in <module>
#     168                 data, target = data.cuda(), target.cuda()
#     169                 optimizer.zero_grad()
# --> 170                 output = model(data)
#     171                 loss = F.nll_loss(output, target)
#     172                 loss.backward()
#
# ~\Anaconda3\envs\rwnn\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# ~\Desktop\datascience\SKT\RandWireNN\model\model.py in forward(self, y)
#      43         y = self.dagly3(y) # [B, chn, 28, 28]
#      44         y = self.dagly4(y) # [B, 2*chn, 14, 14]
# ---> 45         y = self.dagly5(y) # [B, 4*chn, 7, 7]
#      46
#      47         # classifier
#
# ~\Anaconda3\envs\rwnn\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# ~\Desktop\datascience\SKT\RandWireNN\model\dag_layer.py in forward(self, y)
#      50             now = queue.popleft()
#      51             input_list = [outputs[x] for x in self.rev_adjlist[now]]
# ---> 52             feed = torch.stack(input_list, dim=-1)
#      53             outputs[now] = self.nodes[now](feed)
#      54             for v in self.adjlist[now]:
#
# KeyboardInterrupt:

# %%
import torch
model
# Out:
# RandWire(
#   (conv1): Conv2d(1, 39, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (bn1): BatchNorm2d(39, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(39, 78, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (bn2): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dagly3): DAGLayer(
#     (nodes): ModuleList(
#       (0): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (6): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (7): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (8): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (9): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (10): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (11): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (12): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (13): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (14): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (15): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (16): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (17): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (18): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (19): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (20): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (21): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (22): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (23): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (24): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (25): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (26): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (27): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (28): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (29): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (30): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (31): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (dagly4): DAGLayer(
#     (nodes): ModuleList(
#       (0): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (6): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (7): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (8): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (9): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (10): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (11): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (12): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (13): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (14): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (15): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (16): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (17): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (18): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (19): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (20): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (21): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (22): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (23): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (24): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (25): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (26): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (27): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(78, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (28): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (29): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (30): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (31): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(78, 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=78, bias=False)
#           (pointwise): Conv2d(78, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (dagly5): DAGLayer(
#     (nodes): ModuleList(
#       (0): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (6): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (7): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (8): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (9): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (10): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (11): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (12): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (13): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (14): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (15): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (16): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (17): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (18): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (19): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (20): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (21): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (22): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (23): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (24): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (25): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 312, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(312, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (26): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (27): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 156, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (28): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 312, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(312, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (29): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 312, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(312, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (30): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 312, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(312, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (31): NodeOp(
#         (conv): SeparableConv2d(
#           (conv1): Conv2d(156, 156, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=156, bias=False)
#           (pointwise): Conv2d(156, 312, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#         (bn): BatchNorm2d(312, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (convlast): Conv2d(312, 1280, kernel_size=(1, 1), stride=(1, 1))
#   (bnlast): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc): Linear(in_features=1280, out_features=10, bias=True)
# )

# %%
summary(model,(1,244,244))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 39, 122, 122]             390
#        BatchNorm2d-2         [-1, 39, 122, 122]              78
#             Conv2d-3           [-1, 78, 61, 61]          27,456
#        BatchNorm2d-4           [-1, 78, 61, 61]             156
#             Conv2d-5           [-1, 78, 31, 31]             702
#             Conv2d-6           [-1, 78, 31, 31]           6,084
#    SeparableConv2d-7           [-1, 78, 31, 31]               0
#        BatchNorm2d-8           [-1, 78, 31, 31]             156
#             NodeOp-9           [-1, 78, 31, 31]               0
#            Conv2d-10           [-1, 78, 31, 31]             702
#            Conv2d-11           [-1, 78, 31, 31]           6,084
#   SeparableConv2d-12           [-1, 78, 31, 31]               0
#       BatchNorm2d-13           [-1, 78, 31, 31]             156
#            NodeOp-14           [-1, 78, 31, 31]               0
#            Conv2d-15           [-1, 78, 31, 31]             702
#            Conv2d-16           [-1, 78, 31, 31]           6,084
#   SeparableConv2d-17           [-1, 78, 31, 31]               0
#       BatchNorm2d-18           [-1, 78, 31, 31]             156
#            NodeOp-19           [-1, 78, 31, 31]               0
#            Conv2d-20           [-1, 78, 31, 31]             702
#            Conv2d-21           [-1, 78, 31, 31]           6,084
#   SeparableConv2d-22           [-1, 78, 31, 31]               0
#       BatchNorm2d-23           [-1, 78, 31, 31]             156
#            NodeOp-24           [-1, 78, 31, 31]               0
#            Conv2d-25           [-1, 78, 31, 31]             702
#            Conv2d-26           [-1, 78, 31, 31]           6,084
#   SeparableConv2d
[-1, 156, 8, 8]          24,336
#  SeparableConv2d-439            [-1, 156, 8, 8]               0
#      BatchNorm2d-440            [-1, 156, 8, 8]             312
#           NodeOp-441            [-1, 156, 8, 8]               0
#           Conv2d-442            [-1, 156, 8, 8]           1,404
#           Conv2d-443            [-1, 156, 8, 8]          24,336
#  SeparableConv2d-444            [-1, 156, 8, 8]               0
#      BatchNorm2d-445            [-1, 156, 8, 8]             312
#           NodeOp-446            [-1, 156, 8, 8]               0
#           Conv2d-447            [-1, 156, 8, 8]           1,404
#           Conv2d-448            [-1, 156, 8, 8]          24,336
#  SeparableConv2d-449            [-1, 156, 8, 8]               0
#      BatchNorm2d-450            [-1, 156, 8, 8]             312
#           NodeOp-451            [-1, 156, 8, 8]               0
#           Conv2d-452            [-1, 156, 8, 8]           1,404
#           Conv2d-453            [-1, 156, 8, 8]          24,336
#  SeparableConv2d-454            [-1, 156, 8, 8]               0
#      BatchNorm2d-455            [-1, 156, 8, 8]             312
#           NodeOp-456            [-1, 156, 8, 8]               0
#           Conv2d-457            [-1, 156, 8, 8]           1,404
#           Conv2d-458            [-1, 156, 8, 8]          24,336
#  SeparableConv2d-459            [-1, 156, 8, 8]               0
#      BatchNorm2d-460            [-1, 156, 8, 8]             312
#           NodeOp-461            [-1, 156, 8, 8]               0
#           Conv2d-462            [-1, 156, 8, 8]           1,404
#           Conv2d-463            [-1, 156, 8, 8]          24,336
#  SeparableConv2d-464            [-1, 156, 8, 8]               0
#      BatchNorm2d-465            [-1, 156, 8, 8]             312
#           NodeOp-466            [-1, 156, 8, 8]               0
#           Conv2d-467            [-1, 156, 8, 8]           1,404
#           Conv2d-468            [-1, 312, 8, 8]          48,672
#  SeparableConv2d-469            [-1, 312, 8, 8]               0
#      BatchNorm2d-470            [-1, 312, 8, 8]             624
#           NodeOp-471            [-1, 312, 8, 8]               0
#           Conv2d-472            [-1, 156, 8, 8]           1,404
#           Conv2d-473            [-1, 156, 8, 8]          24,336
#  SeparableConv2d-474            [-1, 156, 8, 8]               0
#      BatchNorm2d-475            [-1, 156, 8, 8]             312
#           NodeOp-476            [-1, 156, 8, 8]               0
#           Conv2d-477            [-1, 156, 8, 8]           1,404
#           Conv2d-478            [-1, 312, 8, 8]          48,672
#  SeparableConv2d-479            [-1, 312, 8, 8]               0
#      BatchNorm2d-480            [-1, 312, 8, 8]             624
#           NodeOp-481            [-1, 312, 8, 8]               0
#           Conv2d-482            [-1, 156, 8, 8]           1,404
#           Conv2d-483            [-1, 312, 8, 8]          48,672
#  SeparableConv2d-484            [-1, 312, 8, 8]               0
#      BatchNorm2d-485            [-1, 312, 8, 8]             624
#           NodeOp-486            [-1, 312, 8, 8]               0
#         DAGLayer-487            [-1, 312, 8, 8]               0
#           Conv2d-488           [-1, 1280, 8, 8]         400,640
#      BatchNorm2d-489           [-1, 1280, 8, 8]           2,560
#           Linear-490                   [-1, 10]          12,810
# ================================================================
# Total params: 1,882,722
# Trainable params: 1,882,722
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.23
# Forward/backward pass size (MB): 148.81
# Params size (MB): 7.18
# Estimated Total Size (MB): 156.22
# ----------------------------------------------------------------

# %%
hp.model
# Out:
# {'channel': 78,
#  'classes': 10,
#  'input_maps': 1,
#  'graph0': 'er-01.txt',
#  'graph1': 'er-02.txt',
#  'graph2': 'er-03.txt'}

# %%
args = easydict.EasyDict({
 
        "batchsize": 100,
 
        "epoch": 20,
 
        "gpu": 0,
 
        "out": "result",
 
        "resume": False,
 
        "unit": 1000
 
})

# %%
args.batchsize
# Out:
# 100
